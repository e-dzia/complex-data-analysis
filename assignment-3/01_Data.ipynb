# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('dane/series1.csv')
df1 = df1.rename(columns={'x': 'x1'})
df2 = pd.read_csv('dane/series2.csv')
df2 = df2.rename(columns={'x': 'x2'})
df3 = pd.read_csv('dane/series3.csv')
df3 = df3.rename(columns={'x': 'x3'})

df = pd.concat([df1, df2, df3], axis=1)

# %%
df.head()
# Out:
#          x1        x2        x3
# 0  1.016621  0.883654  0.597161
# 1  0.986977  1.175026  0.778511
# 2  1.962697  1.320331  0.120367
# 3  1.147780  0.786829  1.054462
# 4  1.183671  0.564443 -0.369741

# %%
df.describe()
# Out:
#                  x1            x2            x3
# count  10000.000000  10000.000000  10000.000000
# mean       1.560164      1.218998      0.341367
# std        0.451253      0.343128      0.760687
# min        0.027671      0.260772     -2.590082
# 25%        1.236303      0.960094     -0.175291
# 50%        1.534117      1.187897      0.338872
# 75%        1.870704      1.460557      0.866510
# max        3.117181      2.485598      3.062030

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(data=df, y='x1', x=range(0, 10000))

# %%
df['x1'].hist()

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(data=df, y='x2', x=range(0, 10000))

# %%
df['x2'].hist()

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(data=df, y='x3', x=range(0, 10000))

# %%
df['x3'].hist()
